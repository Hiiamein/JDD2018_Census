# %%
# %load arima_baseline_para.py
#!/usr/bin/env python3

import time
import datetime
import warnings
import numpy as np
import pandas as pd

from pmdarima.arima import auto_arima
from multiprocessing import Pool
from multiprocessing import cpu_count


def data_process(process_id, city_data_list, date_dt, tmp_df_columns):
    print("process {} start".format(process_id))
    preds_df = pd.DataFrame()

    for city_data in city_data_list:
        # print("process {} city {}".format(process_id, city_data))
        district_code = city_data[0]
        sub_df = city_data[1]
        city_code = sub_df['city_code'].iloc[0]
        predict_columns = ['dwell', 'flow_in', 'flow_out']
        tmp_df = pd.DataFrame(data=date_dt, columns=['date_dt'])
        tmp_df['city_code'] = city_code
        tmp_df['district_code'] = district_code

        for column in predict_columns:
            print("process {}: city {}, column {}".format(process_id, district_code, column))
            ts_log = np.log(1 + sub_df[column])
            arima_model = auto_arima(ts_log, start_p=1, max_p=9, start_q=1, max_q=9, max_d=5,
                                     start_P=1, max_P=9, start_Q=1, max_Q=9, max_D=5,
                                     m=7, random_state=2018,
                                     trace=False,
                                     seasonal=True,
                                     error_action='ignore',
                                     suppress_warnings=True,
                                     stepwise=True)

            preds = arima_model.predict(n_periods=15)
            preds = pd.Series(preds)
            preds = np.exp(preds) - 1
            tmp_df = pd.concat([tmp_df, preds], axis=1)

        tmp_df.columns = tmp_df_columns
        preds_df = pd.concat([preds_df, tmp_df], axis=0, ignore_index=True)
        
    print("process {} finished".format(process_id))
    return preds_df


def multiple_prosess():
    start_time = time.clock()
    warnings.filterwarnings('ignore')

    flow_df = pd.read_csv('data/filter/flow_train_filter3.csv')
    flow_df = flow_df.sort_values(by=['city_code', 'district_code', 'date_dt'])

    date_dt = list()
    init_date = datetime.date(2018, 3, 2)

    for delta in range(15):
        _date = init_date + datetime.timedelta(days=delta)
        date_dt.append(_date.strftime('%Y%m%d'))

    district_code_values = flow_df['district_code'].unique()
    preds_df = pd.DataFrame()

    process_num = cpu_count() - 3
    tmp_df_columns = ['date_dt', 'city_code', 'district_code', 'dwell', 'flow_in', 'flow_out']
    city_data_total = [[district_code, flow_df[flow_df["district_code"] == district_code]] for district_code in
                       district_code_values]
    city_index = np.linspace(0, len(city_data_total), process_num + 1, dtype=np.int32)

    pool = Pool(process_num)
    pool_list = [pool.apply_async(data_process, args=(i + 1, city_data_total[city_index[i]: city_index[i + 1]],
                                                      date_dt, tmp_df_columns))
                 for i in np.arange(len(city_index) - 1)]
    pool.close()
    pool.join()
    results = [p.get() for p in pool_list]

    for result in results:
        preds_df = pd.concat([preds_df, result], axis=0, ignore_index=True)

    preds_df = preds_df.sort_values(by=['date_dt'])

    finish_time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    preds_df.to_csv('prediction_{}.csv'.format(finish_time), index=False, header=False)
    end_time = time.clock()
    print("used time: {} minutes".format((end_time - start_time)/60.0))
    print("used time: {:.2f} minutes".format((end_time - start_time)/60.0))

if __name__ == '__main__':
    multiple_prosess()
# Out:
# process 1 start
# process 1: city 032c75c11f45ab3abf41506d616af280, column dwell
# process 1: city 032c75c11f45ab3abf41506d616af280, column flow_in
# process 1: city 032c75c11f45ab3abf41506d616af280, column flow_out
# process 1: city 077ff638b4c221fc3abb88fa9bd499a7, column dwell
# process 1: city 077ff638b4c221fc3abb88fa9bd499a7, column flow_in
# process 1: city 077ff638b4c221fc3abb88fa9bd499a7, column flow_out
# process 1: city 3a3630930e4f054033e0c64a728f759a, column dwell
# process 1: city 3a3630930e4f054033e0c64a728f759a, column flow_in
# process 1: city 3a3630930e4f054033e0c64a728f759a, column flow_out
# process 1: city 4d3b1591070ad975f4c0b7232485980d, column dwell
# process 1: city 4d3b1591070ad975f4c0b7232485980d, column flow_in
# process 1: city 4d3b1591070ad975f4c0b7232485980d, column flow_out
# process 1: city 4fe4bd4a69e1d7a5550d28ef71c8dcaa, column dwell
# process 1: city 4fe4bd4a69e1d7a5550d28ef71c8dcaa, column flow_in
# process 1: city 4fe4bd4a69e1d7a5550d28ef71c8dcaa, column flow_out
# process 1: city 663c41e93447911aaeb2bded1ecdd918, column dwell
# process 1: city 663c41e93447911aaeb2bded1ecdd918, column flow_in
# process 1: city 663c41e93447911aaeb2bded1ecdd918, column flow_out
# process 1: city 76aa9284408ba09d7069f226d6b86a31, column dwell
# process 1: city 76aa9284408ba09d7069f226d6b86a31, column flow_in
# process 1: city 76aa9284408ba09d7069f226d6b86a31, column flow_out
# process 1: city 7809f7e1ce419a80532cf5917f9b34c0, column dwell
# process 1: city 7809f7e1ce419a80532cf5917f9b34c0, column flow_in
# process 1: city 7809f7e1ce419a80532cf5917f9b34c0, column flow_out
# process 1: city 85792b2278de59316d1158f6a97537ec, column dwell
# process 1: city 85792b2278de59316d1158f6a97537ec, column flow_in
# process 1: city 85792b2278de59316d1158f6a97537ec, column flow_out
# process 1: city a07711a54a122bee09726fc7489f2c1b, column dwell
# process 1: city a07711a54a122bee09726fc7489f2c1b, column flow_in
# process 1: city a07711a54a122bee09726fc7489f2c1b, column flow_out
# process 1: city ccbf7a1a33c7c6926366ba5f6e2f1e83, column dwell
# process 1: city ccbf7a1a33c7c6926366ba5f6e2f1e83, column flow_in
# process 1: city ccbf7a1a33c7c6926366ba5f6e2f1e83, column flow_out
# process 1: city 01bb949d16b241654d3be95fa224abc8, column dwell
# process 1: city 01bb949d16b241654d3be95fa224abc8, column flow_in
# process 1: city 01bb949d16b241654d3be95fa224abc8, column flow_out
# process 1: city 09669156636ecb81594f220af7090f07, column dwell
# process 1: city 09669156636ecb81594f220af7090f07, column flow_in
# process 1: city 09669156636ecb81594f220af7090f07, column flow_out
# process 1: city 16206fca49a2a5a29174c651473e9de2, column dwell
# process 1: city 16206fca49a2a5a29174c651473e9de2, column flow_in
# process 1: city 16206fca49a2a5a29174c651473e9de2, column flow_out
# process 1: city 2520d8133ed1363c15a57697c40614d1, column dwell
# process 1: city 2520d8133ed1363c15a57697c40614d1, column flow_in
# process 1: city 2520d8133ed1363c15a57697c40614d1, column flow_out
# process 1: city 2b6555ea85b6a3ac817c7926576d65a9, column dwell
# process 1: city 2b6555ea85b6a3ac817c7926576d65a9, column flow_in
# process 1: city 2b6555ea85b6a3ac817c7926576d65a9, column flow_out
# process 1: city 307185b7aa11f160d45a8595d274f25d, column dwell
# process 1: city 307185b7aa11f160d45a8595d274f25d, column flow_in
# process 1: city 307185b7aa11f160d45a8595d274f25d, column flow_out
# process 1: city 36427b54c6d666453a98398aad52f195, column dwell
# process 1: city 36427b54c6d666453a98398aad52f195, column flow_in
# process 1: city 36427b54c6d666453a98398aad52f195, column flow_out
# process 1: city 402adb2557f9bfb55e876b202ed436c7, column dwell
# process 1: city 402adb2557f9bfb55e876b202ed436c7, column flow_in
# process 1: city 402adb2557f9bfb55e876b202ed436c7, column flow_out
# process 1: city 450fc9a17a3c2eed378b14f27624778d, column dwell
# process 1: city 450fc9a17a3c2eed378b14f27624778d, column flow_in
# process 1: city 450fc9a17a3c2eed378b14f27624778d, column flow_out
# process 1: city 4dba3225999ecab2a33c3398a1b9eb2c, column dwell
# process 1: city 4dba3225999ecab2a33c3398a1b9eb2c, column flow_in
# process 1: city 4dba3225999ecab2a33c3398a1b9eb2c, column flow_out
# process 1: city 5e36de425a507017165ee1625b23f562, column dwell
# process 1: city 5e36de425a507017165ee1625b23f562, column flow_in
# process 1: city 5e36de425a507017165ee1625b23f562, column flow_out
# process 1: city 739d7b5930812338a131df1812734f9c, column dwell
# process 1: city 739d7b5930812338a131df1812734f9c, column flow_in
# process 1: city 739d7b5930812338a131df1812734f9c, column flow_out
# process 1: city 8557deefde49ac19e77889eae2836e22, column dwell
# process 1: city 8557deefde49ac19e77889eae2836e22, column flow_in
# process 1: city 8557deefde49ac19e77889eae2836e22, column flow_out
# process 1: city 8e36f44049175bf28290bd040a329480, column dwell
# process 1: city 8e36f44049175bf28290bd040a329480, column flow_in
# process 1: city 8e36f44049175bf28290bd040a329480, column flow_out
# process 1: city 8e45a723ac5d47626151b4f0759d343e, column dwell
# process 1: city 8e45a723ac5d47626151b4f0759d343e, column flow_in
# process 1: city 8e45a723ac5d47626151b4f0759d343e, column flow_out
# process 1: city 9b476f4792e4302d91e214afd537dfa5, column dwell
# process 1: city 9b476f4792e4302d91e214afd537dfa5, column flow_in
# process 1: city 9b476f4792e4302d91e214afd537dfa5, column flow_out
# process 1: city a4b4f6d5532d10b4a6611c8e9cffb5e8, column dwell
# process 1: city a4b4f6d5532d10b4a6611c8e9cffb5e8, column flow_in
# process 1: city a4b4f6d5532d10b4a6611c8e9cffb5e8, column flow_out
# process 1: city c0293b05819ae31b378c547a987bb987, column dwell
# process 1: city c0293b05819ae31b378c547a987bb987, column flow_in
# process 1: city c0293b05819ae31b378c547a987bb987, column flow_out
# process 1: city dad5b1a26517a039827215846bcaf394, column dwell
# process 1: city dad5b1a26517a039827215846bcaf394, column flow_in
# process 1: city dad5b1a26517a039827215846bcaf394, column flow_out
# process 1: city df94f92b5c9ea5c5bd7098f00840e83a, column dwell
# process 1: city df94f92b5c9ea5c5bd7098f00840e83a, column flow_in
# process 1: city df94f92b5c9ea5c5bd7098f00840e83a, column flow_out
# process 1: city f29b7de70c06c60afadb220115b6918c, column dwell
# process 1: city f29b7de70c06c60afadb220115b6918c, column flow_in
# process 1: city f29b7de70c06c60afadb220115b6918c, column flow_out
# process 1: city fbcd4e601940721b90fefbccc90524f6, column dwell
# process 1: city fbcd4e601940721b90fefbccc90524f6, column flow_in
# process 1: city fbcd4e601940721b90fefbccc90524f6, column flow_out
# process 1: city 178c03faf94e50490bc798e9507008ab, column dwell
# process 1: city 178c03faf94e50490bc798e9507008ab, column flow_in
# process 1: city 178c03faf94e50490bc798e9507008ab, column flow_out
# process 1: city 1d86aa481642ba64ef42e2956339bbad, column dwell
# process 1: city 1d86aa481642ba64ef42e2956339bbad, column flow_in
# process 1: city 1d86aa481642ba64ef42e2956339bbad, column flow_out
# process 1: city 2d9ca395c9405028ca5d6635253d7166, column dwell
# process 1: city 2d9ca395c9405028ca5d6635253d7166, column flow_in
# process 1: city 2d9ca395c9405028ca5d6635253d7166, column flow_out
# process 1: city 3ef7d4a4cd79814c2ee3dfa6724d2fc7, column dwell
# process 1: city 3ef7d4a4cd79814c2ee3dfa6724d2fc7, column flow_in
# process 1: city 3ef7d4a4cd79814c2ee3dfa6724d2fc7, column flow_out
# process 1: city 48305fe4a863757610e25d72b8dac98a, column dwell
# process 1: city 48305fe4a863757610e25d72b8dac98a, column flow_in
# process 1: city 48305fe4a863757610e25d72b8dac98a, column flow_out
# process 1: city 4a33322e6eabfd38b334964c939d07cb, column dwell
# process 1: city 4a33322e6eabfd38b334964c939d07cb, column flow_in
# process 1: city 4a33322e6eabfd38b334964c939d07cb, column flow_out
# process 1: city 50ec193f67e23ca084bb7af4100c1243, column dwell
# process 1: city 50ec193f67e23ca084bb7af4100c1243, column flow_in
# process 1: city 50ec193f67e23ca084bb7af4100c1243, column flow_out
# process 1: city 60d70ece4057ea94fd8c36cc39b91131, column dwell
# process 1: city 60d70ece4057ea94fd8c36cc39b91131, column flow_in
# process 1: city 60d70ece4057ea94fd8c36cc39b91131, column flow_out
# process 1: city 60d9a82c1f961f206c44cdaf618fc15b, column dwell
# process 1: city 60d9a82c1f961f206c44cdaf618fc15b, column flow_in
# process 1: city 60d9a82c1f961f206c44cdaf618fc15b, column flow_out
# process 1: city eb8ef95c3874a09518095f3110c01e2d, column dwell
# process 1: city eb8ef95c3874a09518095f3110c01e2d, column flow_in
# process 1: city eb8ef95c3874a09518095f3110c01e2d, column flow_out
# process 1: city 05e37aecd15e7e3f7fb6dbb8e4713837, column dwell
# process 1: city 05e37aecd15e7e3f7fb6dbb8e4713837, column flow_in
# process 1: city 05e37aecd15e7e3f7fb6dbb8e4713837, column flow_out
# process 1: city 0b28636d08bff292de12f663d522c55f, column dwell
# process 1: city 0b28636d08bff292de12f663d522c55f, column flow_in
# process 1: city 0b28636d08bff292de12f663d522c55f, column flow_out
# process 1: city 12da6611282638727b4f969b4a2ea373, column dwell
# process 1: city 12da6611282638727b4f969b4a2ea373, column flow_in
# process 1: city 12da6611282638727b4f969b4a2ea373, column flow_out
# process 1: city 1df63b98ae38be96c378a9923b4f8c2a, column dwell
# process 1: city 1df63b98ae38be96c378a9923b4f8c2a, column flow_in
# process 1: city 1df63b98ae38be96c378a9923b4f8c2a, column flow_out
# process 1: city 2e24920cddb34084f14af14a1a430291, column dwell
# process 1: city 2e24920cddb34084f14af14a1a430291, column flow_in
# process 1: city 2e24920cddb34084f14af14a1a430291, column flow_out
# process 1: city 62e4009269d5a307a68463796241ef0d, column dwell
# process 1: city 62e4009269d5a307a68463796241ef0d, column flow_in
# process 1: city 62e4009269d5a307a68463796241ef0d, column flow_out
# process 1: city 72183c966cd79d4bcdfa5af3c27bfc46, column dwell
# process 1: city 72183c966cd79d4bcdfa5af3c27bfc46, column flow_in
# process 1: city 72183c966cd79d4bcdfa5af3c27bfc46, column flow_out
# process 1: city 7dfa063fe54cbaf7f7d55e75af1c29e8, column dwell
# process 1: city 7dfa063fe54cbaf7f7d55e75af1c29e8, column flow_in
# process 1: city 7dfa063fe54cbaf7f7d55e75af1c29e8, column flow_out
# process 1: city 9c113e65484f4d502713a851a4995be6, column dwell
# process 1: city 9c113e65484f4d502713a851a4995be6, column flow_in
# process 1: city 9c113e65484f4d502713a851a4995be6, column flow_out
# process 1: city bf04ef9d1a8c56e5c90f249f6c003a80, column dwell
# process 1: city bf04ef9d1a8c56e5c90f249f6c003a80, column flow_in
# process 1: city bf04ef9d1a8c56e5c90f249f6c003a80, column flow_out
# process 1: city c3794023b86136e4d3e2211e2f9e3c83, column dwell
# process 1: city c3794023b86136e4d3e2211e2f9e3c83, column flow_in
# process 1: city c3794023b86136e4d3e2211e2f9e3c83, column flow_out
# process 1: city f00afa5a46437b6b6d945a93d4fc3437, column dwell
# process 1: city f00afa5a46437b6b6d945a93d4fc3437, column flow_in
# process 1: city f00afa5a46437b6b6d945a93d4fc3437, column flow_out
# process 1: city f0d02fabfe4070a5ce6ab74320978d81, column dwell
# process 1: city f0d02fabfe4070a5ce6ab74320978d81, column flow_in
# process 1: city f0d02fabfe4070a5ce6ab74320978d81, column flow_out
# process 1: city f6c260066fc39266a69d4821e12292f1, column dwell
# process 1: city f6c260066fc39266a69d4821e12292f1, column flow_in
# process 1: city f6c260066fc39266a69d4821e12292f1, column flow_out
# process 1: city f7de965674dcbf0d3bb11f4e2ebccfb1, column dwell
# process 1: city f7de965674dcbf0d3bb11f4e2ebccfb1, column flow_in
# process 1: city f7de965674dcbf0d3bb11f4e2ebccfb1, column flow_out
# process 1: city fbfa6ab937d44bb7fde6bc3f84a8957c, column dwell
# process 1: city fbfa6ab937d44bb7fde6bc3f84a8957c, column flow_in
# process 1: city fbfa6ab937d44bb7fde6bc3f84a8957c, column flow_out
# process 1: city 01c2fa70527b0c72808f3bc27eaad4c9, column dwell
# process 1: city 01c2fa70527b0c72808f3bc27eaad4c9, column flow_in
# process 1: city 01c2fa70527b0c72808f3bc27eaad4c9, column flow_out
# process 1: city 31c828ecfa4feeb7c409ee38c8155da0, column dwell
# process 1: city 31c828ecfa4feeb7c409ee38c8155da0, column flow_in
# process 1: city 31c828ecfa4feeb7c409ee38c8155da0, column flow_out
# process 1: city 44dd3778adc48ab269c10f2f1a71b3da, column dwell
# process 1: city 44dd3778adc48ab269c10f2f1a71b3da, column flow_in
# process 1: city 44dd3778adc48ab269c10f2f1a71b3da, column flow_out
# process 1: city 6ebca9d3153de7a6bbad61456d7071c8, column dwell
# process 1: city 6ebca9d3153de7a6bbad61456d7071c8, column flow_in
# process 1: city 6ebca9d3153de7a6bbad61456d7071c8, column flow_out
# process 1: city 795453e682dccb93c5268d53a8c26222, column dwell
# process 1: city 795453e682dccb93c5268d53a8c26222, column flow_in
# process 1: city 795453e682dccb93c5268d53a8c26222, column flow_out
# process 1: city 879c99a1536ce81df8e84c0c9cf6ff68, column dwell
# process 1: city 879c99a1536ce81df8e84c0c9cf6ff68, column flow_in
# process 1: city 879c99a1536ce81df8e84c0c9cf6ff68, column flow_out
# process 1: city 92bdba0a29391ec9e91966056ad4eb35, column dwell
# process 1: city 92bdba0a29391ec9e91966056ad4eb35, column flow_in
# process 1: city 92bdba0a29391ec9e91966056ad4eb35, column flow_out
# process 1: city ac12452bc2dff4b1d376ed517b9f74f4, column dwell
# process 1: city ac12452bc2dff4b1d376ed517b9f74f4, column flow_in
# process 1: city ac12452bc2dff4b1d376ed517b9f74f4, column flow_out
# process 1: city af89ee17bb9525a75ae9ae9ffef3ea80, column dwell
# process 1: city af89ee17bb9525a75ae9ae9ffef3ea80, column flow_in
# process 1: city af89ee17bb9525a75ae9ae9ffef3ea80, column flow_out
# process 1: city b81ef102d38eccfabf7c776fb8d86f5f, column dwell
# process 1: city b81ef102d38eccfabf7c776fb8d86f5f, column flow_in
# process 1: city b81ef102d38eccfabf7c776fb8d86f5f, column flow_out
# process 1: city c7b19f9b6489f5d2a1a41fd3078ae18c, column dwell
# process 1: city c7b19f9b6489f5d2a1a41fd3078ae18c, column flow_in
# process 1: city c7b19f9b6489f5d2a1a41fd3078ae18c, column flow_out
# process 1: city cc000ec2dd2b1c6571e74cecc641656e, column dwell
# process 1: city cc000ec2dd2b1c6571e74cecc641656e, column flow_in
# process 1: city cc000ec2dd2b1c6571e74cecc641656e, column flow_out
# process 1: city e1e140814a5625e65d9cde93cfa259cd, column dwell
# process 1: city e1e140814a5625e65d9cde93cfa259cd, column flow_in
# process 1: city e1e140814a5625e65d9cde93cfa259cd, column flow_out
# process 1: city ed9d83c8bc17101ed0fa453c50181e3c, column dwell
# process 1: city ed9d83c8bc17101ed0fa453c50181e3c, column flow_in
# process 1: city ed9d83c8bc17101ed0fa453c50181e3c, column flow_out
# process 1: city eed0d29bb4d08163ddd02c629a51cfb7, column dwell
# process 1: city eed0d29bb4d08163ddd02c629a51cfb7, column flow_in
# process 1: city eed0d29bb4d08163ddd02c629a51cfb7, column flow_out
# process 1: city f189a9a771409c059ca076d3fd6f8745, column dwell
# process 1: city f189a9a771409c059ca076d3fd6f8745, column flow_in
# process 1: city f189a9a771409c059ca076d3fd6f8745, column flow_out
# process 1: city 03573c6f25ec09f7119eab8c91d2c38d, column dwell
# process 1: city 03573c6f25ec09f7119eab8c91d2c38d, column flow_in
# process 1: city 03573c6f25ec09f7119eab8c91d2c38d, column flow_out
# process 1: city 08751b85e3dc67f2e690cf8945a4d85b, column dwell
# process 1: city 08751b85e3dc67f2e690cf8945a4d85b, column flow_in
# process 1: city 08751b85e3dc67f2e690cf8945a4d85b, column flow_out
# process 1: city 2923188186fb93a5a5d1bd5b6065c697, column dwell
# process 1: city 2923188186fb93a5a5d1bd5b6065c697, column flow_in
# process 1: city 2923188186fb93a5a5d1bd5b6065c697, column flow_out
# process 1: city 3d02638d29eb06d6cf9996fda90aef3b, column dwell
# process 1: city 3d02638d29eb06d6cf9996fda90aef3b, column flow_in
# process 1: city 3d02638d29eb06d6cf9996fda90aef3b, column flow_out
# process 1: city 3f92d69b5335d09f3365beaeec3da4b8, column dwell
# process 1: city 3f92d69b5335d09f3365beaeec3da4b8, column flow_in
# process 1: city 3f92d69b5335d09f3365beaeec3da4b8, column flow_out
# process 1: city 4832cd147ce5a9a9199b0bb03692215b, column dwell
# process 1: city 4832cd147ce5a9a9199b0bb03692215b, column flow_in
# process 1: city 4832cd147ce5a9a9199b0bb03692215b, column flow_out
# process 1: city 4a2ee3a671acbb271743ca0abbcadc70, column dwell
# process 1: city 4a2ee3a671acbb271743ca0abbcadc70, column flow_in
# process 1: city 4a2ee3a671acbb271743ca0abbcadc70, column flow_out
# process 1: city 560818ea9fb3f253fd66a6ab05eec766, column dwell
# process 1: city 560818ea9fb3f253fd66a6ab05eec766, column flow_in
# process 1: city 560818ea9fb3f253fd66a6ab05eec766, column flow_out
# process 1: city 5fd6c349de50d161eca5838f070c889c, column dwell
# process 1: city 5fd6c349de50d161eca5838f070c889c, column flow_in
# process 1: city 5fd6c349de50d161eca5838f070c889c, column flow_out
# process 1: city 6ecd1a38b37826ffdb76fab0b744f042, column dwell
# process 1: city 6ecd1a38b37826ffdb76fab0b744f042, column flow_in
# process 1: city 6ecd1a38b37826ffdb76fab0b744f042, column flow_out
# process 1: city 6f8199333234985aceb0f83bc046a918, column dwell
# process 1: city 6f8199333234985aceb0f83bc046a918, column flow_in
# process 1: city 6f8199333234985aceb0f83bc046a918, column flow_out
# process 1: city 7782cd408e0cdc423dc9f75721bb6223, column dwell
# process 1: city 7782cd408e0cdc423dc9f75721bb6223, column flow_in
# process 1: city 7782cd408e0cdc423dc9f75721bb6223, column flow_out
# process 1: city 82271c9f4c9bf3b072ebe43b29d01caf, column dwell
# process 1: city 82271c9f4c9bf3b072ebe43b29d01caf, column flow_in
# process 1: city 82271c9f4c9bf3b072ebe43b29d01caf, column flow_out
# process 1: city 83d680ca232f903aa3402e7618894ec5, column dwell
# process 1: city 83d680ca232f903aa3402e7618894ec5, column flow_in
# process 1: city 83d680ca232f903aa3402e7618894ec5, column flow_out
# process 1: city 8aef48d33924fa6298b9820b9dde869e, column dwell
# process 1: city 8aef48d33924fa6298b9820b9dde869e, column flow_in
# process 1: city 8aef48d33924fa6298b9820b9dde869e, column flow_out
# process 1: city a7b25de287f5577daa34dd59bc268d6b, column dwell
# process 1: city a7b25de287f5577daa34dd59bc268d6b, column flow_in
# process 1: city a7b25de287f5577daa34dd59bc268d6b, column flow_out
# process 1: city b058ccce8a07d6bc5e9ba7f2bb09fb86, column dwell
# process 1: city b058ccce8a07d6bc5e9ba7f2bb09fb86, column flow_in
# process 1: city b058ccce8a07d6bc5e9ba7f2bb09fb86, column flow_out
# process 1: city bea147450c07d14fd20f45b2290b0f8f, column dwell
# process 1: city bea147450c07d14fd20f45b2290b0f8f, column flow_in
# process 1: city bea147450c07d14fd20f45b2290b0f8f, column flow_out
# process 1: city c540a21b230d60ba07ccfd75c30ba164, column dwell
# process 1: city c540a21b230d60ba07ccfd75c30ba164, column flow_in
# process 1: city c540a21b230d60ba07ccfd75c30ba164, column flow_out
# process 1: city d4f083bd8a1ed9c8cd9041e928e5880c, column dwell
# process 1: city d4f083bd8a1ed9c8cd9041e928e5880c, column flow_in
# process 1: city d4f083bd8a1ed9c8cd9041e928e5880c, column flow_out
# process 1: city de14040efb37a2e07468f98e80577e0e, column dwell
# process 1: city de14040efb37a2e07468f98e80577e0e, column flow_in
# process 1: city de14040efb37a2e07468f98e80577e0e, column flow_out
# process 1: city fc8f364ac301acd5288d01ffba1439d8, column dwell
# process 1: city fc8f364ac301acd5288d01ffba1439d8, column flow_in
# process 1: city fc8f364ac301acd5288d01ffba1439d8, column flow_out
# process 1: city 611597091d964406138868766d513d10, column dwell
# process 1: city 611597091d964406138868766d513d10, column flow_in
# process 1: city 611597091d964406138868766d513d10, column flow_out
# process 1 finished
# used time: 0.04766666666666667 minutes
# used time: 0.05 minutes
